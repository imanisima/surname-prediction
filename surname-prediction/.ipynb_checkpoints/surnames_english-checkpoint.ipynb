# %% [markdown]
# ## Introduction to Sequence Modeling - Russian vs English Surnames

# %% [markdown]
# ---
# ### Goal
# ---
#
# Develop and classifier for Russian vs English surnames.
#
# In this iteration we are going to:
# * Compute bigram frequencies for English names.
# * Compute bigram frequencies for Russian names.
# * Develop a bag of bigrams model for distinguishing English and Russian names.
# * Implement Katz's Back-Off Model Smoothing
# * Test performance of model using English data.
#
# ------

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import re

# %%
import nltk
# from nltk import bigrams, trigrams, word_tokenize
import collections
from collections import defaultdict, Counter

from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk.corpus import brown # corpus of english words

# %%
# from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB # Multi Naive Bayes with discrete values

from sklearn.feature_extraction.text import CountVectorizer # tokenize texts/build vocab
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer # tokenizes text and normalizes

# %% [markdown]
# ---
# ### Let's perform some EDA
#
# ---

# %%
# read the csv file into data frame.
surname_csv = "data_set/russian_and_english_dev.csv"
surname_df = pd.read_csv(surname_csv, index_col = None, encoding="UTF-8")

# %%
# rename dev data columns.
surname_df.rename(columns = {'Unnamed: 0':'surname', 'Unnamed: 1':'nationality'}, inplace = True)

# %% [markdown]
# #### Features Exploration

# %%
# removing non-alphabetic characters 
# surname_df = surname_df['surname'].apply(lambda x: re.sub('[^a-zA-Z]', '', x))
surname_df
# Out:
#            surname nationality
# 0        Mokrousov     Russian
# 1            Nurov     Russian
# 2         Judovich     Russian
# 3     Mikhailjants     Russian
# 4       Jandarbiev     Russian
# ...            ...         ...
# 1301        Foxall     English
# 1302         Cowan     English
# 1303     Wrightson     English
# 1304          Loft     English
# 1305          Bird     English
#
# [1306 rows x 2 columns]

# %%
# Retrieve English names only
english_df = surname_df.loc[surname_df["nationality"] == "English"]
english_df = english_df[["surname"]]
english_df.head()
# Out:
#        surname
# 940  Fairhurst
# 941  Wateridge
# 942     Nemeth
# 943    Moroney
# 944    Goodall

# %%
# save all english names in txt file
english_df.to_csv("data_set/english-corpus/english_names.txt", sep='\t', index=False, header=False)

# %%
# Russian names only
russian_df = surname_df.loc[surname_df["nationality"] == "Russian"]
russian_df = russian_df[["surname"]]
russian_df.head()
# Out:
#         surname
# 0     Mokrousov
# 1         Nurov
# 2      Judovich
# 3  Mikhailjants
# 4    Jandarbiev

# %%
russian_df.to_csv("data_set/russian-corpus/russian_names.txt", sep='\t', index=False, header=False)

# %% [markdown]
# ---
# ### Create New Corpus
#
# ---
# Create a new corpus of English and Russian names to be used for the n_gram model.

# %%
# eng_gram = defaultdict(lambda: defaultdict(lambda: 0))
# rus_gram = defaultdict(lambda: defaultdict(lambda: 0))

# %%
# corpus_root = 'data_set/english-corpus/'
# english_names = PlaintextCorpusReader(corpus_root, '.*')
# english_names.words('english_names.txt')

names = open("data_set/corpus/english_names.txt", "r")
english_names = [x.rstrip() for x in names.readlines()]
english_names = [x.lower() for x in english_names]
english_names
# Out:
# ['fairhurst',
#  'wateridge',
#  'nemeth',
#  'moroney',
#  'goodall',
#  'agar',
#  'thonon',
#  'duggan',
#  'nash',
#  'herbert',
#  'mcarthur',
#  'moriarty',
#  'douthwaite',
#  'dell',
#  'wakeham',
#  'mottram',
#  'beamish',
#  'karne',
#  'greenwood',
#  'ullman',
#  'aldred',
#  'darlington',
#  'judd',
#  'hicks',
#  'kay',
#  'dervish',
#  'oakley',
#  'morrison',
#  'bethell',
#  'vaughn',
#  'knox',
#  'iles',
#  'trattles',
#  'gibbins',
#  'whelan',
#  'mctaggart',
#  'charnock',
#  'thorley',
#  'thorpe',
#  'garland',
#  'gunter',
#  'turland',
#  'turney',
#  'reisser',
#  'ruff',
#  'newall',
#  'sheppard',
#  'knigge',
#  'davey',
#  'rodrigues',
#  'smullen',
#  'alam',
#  'bradshaw',
#  'kingston',
#  'pelling',
#  'auberton',
#  'kennett',
#  'newham',
#  'ware',
#  'millar',
#  'wallis',
#  'sugden',
#  'butler',
#  'lofthouse',
#  'prendergast',
#  'wragg',
#  'francis',
#  'eddleston',
#  'sykes',
#  'thurston',
#  'ullmann',
#  'reynolds',
#  'eggison',
#  'jackson',
#  'savage',
#  'ransom',
#  'holdsworth',
#  'hiscocks',
#  'dick',
#  'warden',
#  'powis',
#  'dunford',
#  'vickars',
#  'johns',
#  'mcconnell',
#  'leigh',
#  'gillan',
#  'pennell',
#  'greening',
#  'hopkinson',
#  'storey',
#  'dyde',
#  'odam',
#  'robins',
#  'thackray',
#  'derrick',
#  'olson',
#  'martinez',
#  'gascoyne',
#  'lawther',
#  'odonnell',
#  'wolf',
#  'rafferty',
#  'manson',
#  'pyle',
#  'umney',
#  'number',
#  'toland',
#  'more',
#  'kenley',
#  'underwood',
#  'kinch',
#  'monaghan',
#  'kenrick',
#  'redmond',
#  'firth',
#  'essam',
#  'rixon',
#  'isman',
#  'trueman',
#  'neilsen',
#  'tobin',
#  'napper',
#  'elsmore',
#  'kore',
#  'shand',
#  'partington',
#  'parratt',
#  'alker',
#  'neyland',
#  'pasfield',
#  'kilroy',
#  'tarrant',
#  'elkin',
#  'oatway',
#  'leese',
#  'veitch',
#  'sellars',
#  'rudd',
#  'oloughlin',
#  'stockley',
#  'harrison',
#  'grange',
#  'cullen',
#  'connell',
#  'jardine',
#  'yarwood',
#  'ironman',
#  'crump',
#  'adler',
#  'yates',
#  'armer',
#  'reyes',
#  'brady',
#  'stannard',
#  'farhall',
#  'crook',
#  'thurlow',
#  'plummer',
#  'rainey',
#  'vinton',
#  'falconer',
#  'yomkins',
#  'bing',
#  'damon',
#  'holder',
#  'sneddon',
#  'hodson',
#  'polson',
#  'tovar',
#  'moran',
#  'virgo',
#  'peake',
#  'collinson',
#  'wells',
#  'drury',
#  'townsend',
#  'longhurst',
#  'bell',
#  'dibble',
#  'fields',
#  'yardley',
#  'jackman',
#  'fitzpatrick',
#  'boden',
#  'rousset',
#  'thornton',
#  'parkes',
#  'burns',
#  'chisholm',
#  'edgson',
#  'nutman',
#  'parmar',
#  'ventura',
#  'veale',
#  'howell',
#  'curley',
#  'ropple',
#  'wilkshire',
#  'rossi',
#  'sutherland',
#  'ohara',
#  'kydd',
#  'verdon',
#  'wootton',
#  'abrams',
#  'morton',
#  'stringer',
#  'jarratt',
#  'wakefield',
#  'rogerson',
#  'gould',
#  'flannery',
#  'shipley',
#  'twine',
#  'wooldridge',
#  'kinrade',
#  'glenn',
#  'prevost',
#  'waite',
#  'binnington',
#  'travill',
#  'kirby',
#  'baldwin',
#  'lawlor',
#  'maguire',
#  'pearce',
#  'pullen',
#  'perry',
#  'leys',
#  'knoxville',
#  'eyre',
#  'luttrell',
#  'winman',
#  'eldridge',
#  'roche',
#  'bouvet',
#  'foulkes',
#  'easen',
#  'rhodes',
#  'addison',
#  'temple',
#  'oddie',
#  'dougherty',
#  'stack',
#  'clark',
#  'whittaker',
#  'astley',
#  'simms',
#  'oaks',
#  'dawson',
#  'jasper',
#  'downer',
#  'pateman',
#  'deverell',
#  'peal',
#  'emery',
#  'youssouf',
#  'houlton',
#  'aldworth',
#  'elcock',
#  'jubb',
#  'petersen',
#  'gander',
#  'bateman',
#  'downey',
#  'dunlop',
#  'dutt',
#  'lakey',
#  'gilmour',
#  'eyles',
#  'downes',
#  'keeley',
#  'rootham',
#  'bourne',
#  'creasey',
#  'geyer',
#  'pendlebury',
#  'tocher',
#  'black',
#  'killick',
#  'west',
#  'keys',
#  'odling',
#  'arnott',
#  'ashley',
#  'fraser',
#  'rick',
#  'burge',
#  'florey',
#  'eedie',
#  'dowling',
#  'aspey',
#  'stedman',
#  'hibbert',
#  'eade',
#  'smyth',
#  'philips',
#  'hussein',
#  'wears',
#  'friend',
#  'pett',
#  'vancoller',
#  'glen',
#  'cresswell',
#  'lathey',
#  'underhill',
#  'webber',
#  'unsworth',
#  'wickens',
#  'zaoui',
#  'tidmarsh',
#  'thorp',
#  'harrop',
#  'logan',
#  'ingram',
#  'keight',
#  'manning',
#  'curtis',
#  'gunston',
#  'graham',
#  'brett',
#  'driffield',
#  'arah',
#  'denney',
#  'godwin',
#  'turford',
#  'kaur',
#  'stock',
#  'stamp',
#  'cummins',
#  'cooper',
#  'marr',
#  'alford',
#  'robe',
#  'norris',
#  'forbes',
#  'hannam',
#  'gaudin',
#  'kouma',
#  'dolton',
#  'riley',
#  'tickner',
#  'grimshaw',
#  'hinton',
#  'leonard',
#  'sayers',
#  'deeley',
#  'close',
#  'klein',
#  'chauhan',
#  'wray',
#  'poyser',
#  'fulleron',
#  'sims',
#  'thomas',
#  'weaver',
#  'gadsden',
#  'vinicombe',
#  'fenwick',
#  'western',
#  'foxall',
#  'cowan',
#  'wrightson',
#  'loft',
#  'bird']

# %%
# corpus_root = 'data_set/russian-corpus/'
# russian_names = PlaintextCorpusReader(corpus_root, '.*')
# russian_names.words('russian_names.txt')

names = open("data_set/corpus/russian_names.txt", "r")
russian_names = [x.rstrip() for x in names.readlines()]
russian_names = [x.lower() for x in russian_names]
russian_names
# Out:
# ['mokrousov',
#  'nurov',
#  'judovich',
#  'mikhailjants',
#  'jandarbiev',
#  'govyadin',
#  'tubylov',
#  'tunkin',
#  'turetsky',
#  'remyannikov',
#  'adam',
#  'ablesimov',
#  'bakastov',
#  'munin',
#  'tsenkovsky',
#  'polikarpov',
#  'dogel',
#  'janek',
#  'obolonsky',
#  'marhasin',
#  'abdrashitov',
#  'mochalin',
#  'rifkind',
#  'nasonov',
#  'abramchuk',
#  'pohlebaev',
#  'murov',
#  'timaev',
#  'jminko',
#  'pavlenkov',
#  'gaur',
#  'bekhoev',
#  'vainson',
#  'mikhailidi',
#  'kartunov',
#  'batchaev',
#  'jukhman',
#  'talkov',
#  'bagmevsky',
#  'jakimchik',
#  'vaidanovich',
#  'vavkin',
#  'privalihin',
#  'gujavin',
#  'jijilev',
#  'guk',
#  'drozdetsky',
#  'ukhov',
#  'muijel',
#  'avdulov',
#  'zhavoronkov',
#  'tolbuhin',
#  'ryjkin',
#  'rahalsky',
#  'minchenkov',
#  'yuhma',
#  'glavinsky',
#  'zinovin',
#  'zhitnikov',
#  'musalnikov',
#  'yanpolsky',
#  'richter',
#  'hamukov',
#  'ageitchik',
#  'bibler',
#  'hismatulov',
#  'bakihanov',
#  'virenius',
#  'avtokratov',
#  'egin',
#  'dubrowski',
#  'jitny',
#  'mojar',
#  'lihtentul',
#  'gulenko',
#  'awtokratoff',
#  'mogila',
#  'gaspirovich',
#  'razygrin',
#  'bauman',
#  'jilenkov',
#  'porohovschikov',
#  'yatzkevich',
#  'hlystun',
#  'shirkovets',
#  'nuriev',
#  'saigin',
#  'utugunov',
#  'lihtenshtein',
#  'agaryshev',
#  'matzotsky',
#  'porus',
#  'molotilov',
#  'jekov',
#  'goloborodov',
#  'pekhotin',
#  'rotar',
#  'halaev',
#  'abbakumovsky',
#  'jamsuev',
#  'scetintsev',
#  'tzallagov',
#  'piskovoy',
#  'agdaroff',
#  'lysenny',
#  'isanin',
#  'kartashkin',
#  'eretzky',
#  'serednitsky',
#  'baibursky',
#  'zhukovich',
#  'jagupets',
#  'bibishev',
#  'olenev',
#  'mikhasenko',
#  'havroshkin',
#  'belbaev',
#  'jidilin',
#  'homutnikov',
#  'lyjenkov',
#  'tikhov',
#  'luts',
#  'agnivtsev',
#  'mahlai',
#  'kalita',
#  'jikin',
#  'hunov',
#  'nurmuhametov',
#  'velovsky',
#  'zhilin',
#  'homich',
#  'muldashev',
#  'vasyukevich',
#  'fomintsev',
#  'liberzon',
#  'zhikin',
#  'bestujev',
#  'tugai',
#  'ponomarkov',
#  'djahaya',
#  'djunusov',
#  'makhankov',
#  'oborin',
#  'zhulev',
#  'auslender',
#  'bagmevski',
#  'bahmutov',
#  'pribylovsky',
#  'abasov',
#  'zhelaev',
#  'mikhalkov',
#  'bahchivandzhi',
#  'hankeev',
#  'yuhimuk',
#  'tchamushev',
#  'yakovkin',
#  'batchev',
#  'artyushkov',
#  'zharkovsky',
#  'liverovsky',
#  'joludev',
#  'jongolovich',
#  'jafaev',
#  'vaisfeld',
#  'chernin',
#  'zhekov',
#  'holin',
#  'kalgashkin',
#  'zastrozhny',
#  'jurko',
#  'uchaev',
#  'gridnev',
#  'geftler',
#  'priymak',
#  'zherebko',
#  'bakhusov',
#  'jankis',
#  'bagimov',
#  'evstratov',
#  'lutovich',
#  'zaslavets',
#  'baka',
#  'jvykin',
#  'baidachny',
#  'homusko',
#  'shaihutdinov',
#  'eirih',
#  'vantenkov',
#  'markushin',
#  'dzhibladze',
#  'baushev',
#  'onchukov',
#  'alchangyan',
#  'poninsky',
#  'tumin',
#  'antonts',
#  'habalov',
#  'evsyukov',
#  'chartorizhsky',
#  'hlopkov',
#  'babenchikov',
#  'zhuravkov',
#  'endzelin',
#  'remez',
#  'vainunas',
#  'eidinov',
#  'abolin',
#  'sheludchenko',
#  'abdulkadyrov',
#  'schepotkin',
#  'mollo',
#  'grosu',
#  'alshtut',
#  'jerebtsov',
#  'martyushev',
#  'charykov',
#  'govorov',
#  'awakoff',
#  'martin',
#  'artyukhov',
#  'awalishwili',
#  'agabekoff',
#  'iskander',
#  'tokarev',
#  'agarev',
#  'martsinkovsky',
#  'jakimychev',
#  'daugelo',
#  'yadrikhinsky',
#  'vakulentchuk',
#  'rapota',
#  'jurkovsky',
#  'nurkaev',
#  'veselago',
#  'uzhvy',
#  'bahtiyarov',
#  'bezrukikh',
#  'grokhar',
#  'vertman',
#  'zhigin',
#  'adleroff',
#  'ruzhnikov',
#  'finov',
#  'rukhtoev',
#  'martyanov',
#  'kaliberda',
#  'mikhmel',
#  'tzekhansky',
#  'gramberg',
#  'adamyants',
#  'gaganov',
#  'ajogin',
#  'balagul',
#  'gagemeister',
#  'taloverov',
#  'researcher',
#  'virichev',
#  'velikih',
#  'kachalin',
#  'awrorin',
#  'vedischev',
#  'tikhonov',
#  'baibikov',
#  'pitenin',
#  'basov',
#  'pohodun',
#  'bazulin',
#  'tzehmistrenko',
#  'dubrovsky',
#  'awalyan',
#  'mordovin',
#  'fadeechev',
#  'vilin',
#  'dublin',
#  'porokhovschikov',
#  'tselikov',
#  'scheblykin',
#  'jadanovsky',
#  'vakser',
#  'awinoff',
#  'reks',
#  'tulintsev',
#  'rempler',
#  'vins',
#  'baklastov',
#  'uhovsky',
#  'shamgulov',
#  'harisov',
#  'babadzhanov',
#  'zasulich',
#  'saidulaev',
#  'nejinsky',
#  'glaz',
#  'eroschenkov',
#  'zelentsov',
#  'tikhonenko',
#  'govyrin',
#  'gudoshin',
#  'dzhavahishvili',
#  'gorchilin',
#  'didenko',
#  'jirov',
#  'babkov',
#  'glaziev',
#  'vanshenkin',
#  'adler',
#  'shakhno',
#  'grigoriadi',
#  'bagautdinov',
#  'elebaev',
#  'havanov',
#  'baikin',
#  'vanzha',
#  'grokhovsky',
#  'babak',
#  'hinchin',
#  'fisun',
#  'dzhabrailov',
#  'zolotarevsky',
#  'lychakov',
#  'yakovenko',
#  'yanko',
#  'bakhlulzade',
#  'kartamyshev',
#  'mojin',
#  'nejdanov',
#  'zinkevich',
#  'muzychka',
#  'zitev',
#  'dijbak',
#  'moldovanov',
#  'yakhin',
#  'batchinsky',
#  'shelting',
#  'janovsky',
#  'bazhov',
#  'rukhimovich',
#  'zhanimov',
#  'azhnikoff',
#  'gribovsky',
#  'tundykov',
#  'belikovich',
#  'lyzhenkov',
#  'shaidenko',
#  'djanibekov',
#  'shenshin',
#  'yablonowsky',
#  'turusin',
#  'jbankov',
#  'tzalikov',
#  'glukhotko',
#  'helvas',
#  'hafizov',
#  'pendyuhov',
#  'otrokhov',
#  'yuzvikov',
#  'kabakov',
#  'hanukov',
#  'novokhatsky',
#  'pakhmutov',
#  'tsval',
#  'lezhankin',
#  'vyborny',
#  'eidelman',
#  'harlampovich',
#  'gorchatov',
#  'jatzuba',
#  'belokhin',
#  'zhabsky',
#  'tchekhovsky',
#  'liberman',
#  'timirev',
#  'pochtennyh',
#  'porosyuk',
#  'agranovski',
#  'altman',
#  'pochivalov',
#  'elepov',
#  'tzai',
#  'mihalenkov',
#  'hakhulin',
#  'zhemaldinov',
#  'adelkhanov',
#  'penkin',
#  'neverov',
#  'matskevich',
#  'dzhunkovsky',
#  'jivlyuk',
#  'lezhava',
#  'bakhin',
#  'behtold',
#  'gromyko',
#  'jivin',
#  'katsuba',
#  'neznanov',
#  'shakhmaev',
#  'drozdkov',
#  'handjyan',
#  'tikhankin',
#  'janovitsky',
#  'porosenkov',
#  'alpert',
#  'remchukov',
#  'abeltsev',
#  'gachinsky',
#  'barannikov',
#  'to the first page',
#  'jageman',
#  'uemov',
#  'isangulov',
#  'johov',
#  'djisev',
#  'pypin',
#  'lilov',
#  'djamaldinov',
#  'gromyhalin',
#  'lihov',
#  'emchenko',
#  'gludin',
#  'zherdev',
#  'ilyahin',
#  'onischuk',
#  'kalaberda',
#  'zimnuhov',
#  'hanjin',
#  'tchekis',
#  'bakhshiev',
#  'fabri',
#  'anikst',
#  'zeifert',
#  'balashev',
#  'tsevlonsky',
#  'charushkin',
#  'pokhvisnev',
#  'shakhnazarov',
#  'vankov',
#  'chepik',
#  'chugunov',
#  'tobolev',
#  'astyrev',
#  'chajegov',
#  'getman',
#  'livshin',
#  'leibovsky',
#  'dzhikaev',
#  'yagudin',
#  'zheronkin',
#  'zhorov',
#  'baklashov',
#  'tchekmezov',
#  'rihter',
#  'mikhailyuk',
#  'bakinoff',
#  'bakhtoff',
#  'jegunov',
#  'zhushman',
#  'gulkin',
#  'nureev',
#  'jerebko',
#  'vaiserman',
#  'rotast',
#  'yagodin',
#  'baigushev',
#  'nesis',
#  'jugin',
#  'otstavnov',
#  'baum',
#  'bazovsky',
#  'bagmet',
#  'chuhonkin',
#  'kalashnik',
#  'tamanyan',
#  'talitskikh',
#  'baigildeev',
#  'zhernov',
#  'prokurorov',
#  'makhmudov',
#  "tsel'ko",
#  'to the first page',
#  'averchenko',
#  'baevsky',
#  'porublev',
#  'yudochkin',
#  'dubrovin',
#  'jatsyk',
#  'yakubov',
#  'yahlakov',
#  'pakharkov',
#  'mihnenko',
#  'hlobystin',
#  'batugin',
#  'hublaryan',
#  'zhitomirsky',
#  'rogalnikov',
#  'vanchugov',
#  'evsyutin',
#  'juravliov',
#  'ryzhih',
#  'abelyan',
#  'deulenko',
#  'geroev',
#  'nyago',
#  'honenev',
#  'piskotin',
#  'martinenas',
#  'dahnov',
#  'katzarev',
#  'frolov',
#  'anoprienko',
#  'donchak',
#  'lebsky',
#  'zhadkevich',
#  'mulin',
#  'atazhakhov',
#  'zimenkov',
#  'eingorn',
#  'haraz',
#  'dudchik',
#  'serejkin',
#  'likhonosov',
#  'yapparov',
#  'jija',
#  'porohov',
#  'babintsev',
#  'zhdanovsky',
#  'hamadeev',
#  'hlyzov',
#  'dzheladze',
#  'vakitchev',
#  'vagner',
#  'gluharev',
#  'lozinsky',
#  'avdiysky',
#  'babadei',
#  'shangin',
#  'isachenkov',
#  'mujkaterov',
#  'eliashberg',
#  'zheltukhin',
#  'glazatov',
#  'maksimovsky',
#  'turoverov',
#  'ryzhov',
#  'mischenko',
#  'zhgutov',
#  'baevski',
#  'haptahaev',
#  'himich',
#  'jafarov',
#  'anisfeld',
#  'vasserman',
#  'trukhanov',
#  'awerbuh',
#  'leiviman',
#  'jerebyatiev',
#  'granitov',
#  'andreyanov',
#  'vaver',
#  'jadrov',
#  'mahovikov',
#  'gordopolov',
#  'schepovskih',
#  'drojjin',
#  'zhurkov',
#  'glazyrin',
#  'tokmakov',
#  'judkov',
#  'mikhaleiko',
#  'lepikhov',
#  'lygin',
#  'vysotsky',
#  'hamatnurov',
#  'tzarsky',
#  'vainrub',
#  'vilyams',
#  'luppian',
#  'divin',
#  'pahmutov',
#  'kalesnik',
#  'birkin',
#  'valetov',
#  'biryuzov',
#  'bektimirov',
#  'djanakavov',
#  'yufit',
#  'belotserkovsky',
#  'harev',
#  'zolotenkov',
#  'nosko',
#  'nahutin',
#  'baklykoff',
#  'jilin',
#  'hapaev',
#  'herovets',
#  'vistitsky',
#  'isaikov',
#  'minnulin',
#  'to the first page',
#  'imbulgin',
#  'raihlin',
#  'dubnyakov',
#  'heraskov',
#  'katznelson',
#  'martov',
#  'antoschin',
#  'rogalev',
#  'vanzhula',
#  'awdyushin',
#  'penkov',
#  'janshin',
#  'gudim',
#  'awerkin',
#  'tselikovsky',
#  'pavlenok',
#  'grigoriev',
#  'tzann-kay-si',
#  'maksimovich',
#  'rjavinsky',
#  'hautiev',
#  'remenny',
#  'daragan',
#  'pehterev',
#  'kachanovsky',
#  'jakubovich',
#  'horuzhenko',
#  'chertischev',
#  'hamlov',
#  'jernevsky',
#  'gudjabidze',
#  'marsky',
#  'halikov',
#  'lim',
#  'veselovsky',
#  'potsepkin',
#  'gasnikov',
#  'awerkieff',
#  'ruzsky',
#  'almyashkin',
#  'bazylev',
#  'granov',
#  'dogadaev',
#  'dahin',
#  'paivin',
#  'hanzhin',
#  'rekshinsky',
#  'tsaran',
#  'tupikin',
#  'harito',
#  'rujilo',
#  'rahvalov',
#  'averkov',
#  'mahotin',
#  'bahtinoff',
#  'nevelsky',
#  'to the first page',
#  'mintskovsky',
#  'levitzky',
#  'chekletsov',
#  'dovgalev',
#  'gudovsky',
#  'avelichev',
#  'raizer',
#  'rakhil',
#  'val',
#  'moshenkov',
#  'hubiev',
#  'averbah',
#  'lapikov',
#  'vedrinsky',
#  'halipov',
#  'gafarov',
#  'minchev',
#  'datsenko',
#  'bekhtin',
#  'zinevich',
#  'tuganbaev',
#  'dubinkin',
#  'valaev',
#  'ilyakhin',
#  'jitnikov',
#  'glukhonkov',
#  'mikhailin',
#  'zhilenkov',
#  'avzalov',
#  'raikhman',
#  'talalai',
#  'morzhitsky',
#  'antyuganov',
#  'zolotarev',
#  'awerchenko',
#  'bahir',
#  'nosikov',
#  'awercheff',
#  'kabuzan',
#  'bazilevsky',
#  'yakhot',
#  'loitzyansky',
#  'yablochkin',
#  'molodojenov',
#  'saifulaev',
#  'chukhonkin',
#  'mahin',
#  'muzhikov',
#  'yuzhilin',
#  'holodnyh',
#  'fionov',
#  'baikovski',
#  'serjantov',
#  'livadny',
#  'dienko',
#  'serejnikov',
#  'guldreih',
#  'batukov',
#  'timonnikov',
#  'badeschenkov',
#  'zhirnyakov',
#  'vasyagin',
#  'harchev',
#  'lezhenko',
#  'birilev',
#  'helashvili',
#  'rehbinder',
#  'vozgov',
#  'beloborodov',
#  'avrorov',
#  'gallutdinov',
#  'antonchenkov',
#  'matsakov',
#  'gruschak',
#  'ladyjets',
#  'abuhov',
#  'chehladze',
#  'dobronos',
#  'dikul',
#  'adlerberg',
#  'pentin',
#  'uhin',
#  'engver',
#  'raikhelson',
#  'luhovitsky',
#  'zharov',
#  'saifutdinov',
#  'pyrkov',
#  'limarev',
#  'saksonov',
#  'shenfeldt',
#  'ajiganov',
#  'zhivlyuk',
#  'minkovich',
#  'hevrolin',
#  'bazen',
#  'jalamov',
#  'yakubchik',
#  'babusenko',
#  'emohonov',
#  'gafin',
#  'rakhlevsky',
#  'bass',
#  'zhirnikov',
#  'bachish',
#  'vedenov',
#  'govendyaev',
#  'piruzyan',
#  'rovner',
#  'chanyshev',
#  'kalinochkin',
#  'berezitzky',
#  'grushko',
#  'heveshi',
#  'bazaev',
#  'parensky',
#  'tsvilgnev',
#  'bakhrakh',
#  'moisinovich',
#  'togunov',
#  'yamschikov',
#  'jovnir',
#  'toien',
#  'antopolsky',
#  'vanichev',
#  'tomjevsky',
#  'gershkovich',
#  'bakunov',
#  'dobrushkin',
#  'eberg',
#  'hanifatullin',
#  'doga',
#  'ablesimoff',
#  'jgutov',
#  'agibaloff',
#  'ebers',
#  'rahletsky',
#  'omelin',
#  'ryzhkov',
#  'babadjan',
#  'gul',
#  'limitovsky',
#  'mokeev',
#  'shalov',
#  'tzalko',
#  'jukov',
#  'agin',
#  'shenagin',
#  'vyrodkov',
#  'velikin',
#  'limarov',
#  'trukhnin',
#  'galenkovsky',
#  'bakun',
#  'vyazmin',
#  'avilkin',
#  'lohvitsky',
#  'talapa',
#  'abrikosoff',
#  'bagmut',
#  'jakovlev',
#  'balabolkin',
#  'balahowsky',
#  'trukhanovsky',
#  'losyukov',
#  'molyakov',
#  'vikhirev',
#  'katzan',
#  'yakubik',
#  'durasov',
#  'lutchenkov',
#  'bestolov',
#  'hadarin',
#  'shalikov',
#  'sapon',
#  'kablukov',
#  'frolandin',
#  'shirko',
#  'timerhanov',
#  'zasuhin',
#  'bakhtadze',
#  'nyuhtilin',
#  'anuriev',
#  'lishin',
#  'ukhovsky',
#  'shenderovich',
#  'vinaver',
#  "pokhmel'nyh",
#  'ryzhkovsky',
#  'agranoff',
#  'vilmont',
#  'diyajev',
#  'muru',
#  'abramovitch',
#  'mihalchev',
#  'deshkin',
#  'zharkov',
#  'baev',
#  'onusaitis',
#  'todriya',
#  'dubasov',
#  'lebedenko',
#  'pietsuh',
#  'vislobokov',
#  'shahin',
#  'jarov',
#  'agayan',
#  'gerschcovich',
#  'tzagunov',
#  'jujlev',
#  'filipov',
#  'hloponin',
#  'holodilov',
#  'lysenko',
#  'veprentsov',
#  'belotserkovets',
#  'shamin',
#  'jmotov',
#  'zholtovsky',
#  'dobrovsky',
#  'shakhnazaryants',
#  'mogilnikov',
#  'eletskih',
#  'dubrouski',
#  'limar',
#  'babosov',
#  'vertogradsky',
#  'vilonov',
#  'yakon',
#  'mikhailyants',
#  'haidakin',
#  'tovarovsky',
#  'dargevich',
#  'yakimychev',
#  'marholenko',
#  'gorsky',
#  'ponizovsky',
#  'janaki',
#  'awramtchik',
#  'elentuh',
#  'makhno',
#  'marmazov',
#  'agalov',
#  'enikeev',
#  'rahil',
#  'talbaev',
#  'biron',
#  'makhov',
#  'portnyakov',
#  'gladtsin',
#  'bakalinsky',
#  'vanchagov',
#  'cheruhin',
#  'diky',
#  'vyazalov',
#  'zhivov',
#  'nyrtsev',
#  'kartashev',
#  'ajaev',
#  'zhulyabin',
#  'bein',
#  'seredohov',
#  'saker',
#  'vedyaev',
#  'zheryapin',
#  'kaletsky',
#  'dubatkov',
#  'tokunov',
#  'jukhno',
#  'lupin',
#  'yam',
#  'gribkov',
#  'dzhibuti',
#  'vazhov',
#  'tupalo',
#  'tzakh',
#  'jebrovsky',
#  'shakhmin',
#  'jakubov',
#  'schugorev',
#  'jakimov',
#  'agranovsky',
#  'kats',
#  'velmukin']

# %% [markdown]
# -------
# ### Calculate Frequencies and Probabilities
#
# -----

# %%
# def generate_bigrams(word):
#     lower = word[:-1]
#     upper = word[1:]
#     bigram_gen = map(lambda l,u: l+u, lower, upper)
#     for bigram in bigram_gen:
#         yield bigram

# %%
# def compute_frequencies(data, language):
#     """data is an iterable.    Frequency counts for both Bigrams and Unigrams,  on a specific language
#     """
#     bigram_freqs = {a+b:0 for (a,b) in itertools.product(
#             string.ascii_lowercase, string.ascii_lowercase)}
#     letter_freqs = {a:0 for a in string.ascii_lowercase}

#     filtered = filter(lambda x: x[1] == language, data)

#     for (name, _) in filtered:
#         for letter in name:
#             letter_freqs[letter] += 1
#         for bigram in generate_bigrams(name):
#             bigram_freqs[bigram] += 1

#     return bigram_freqs, letter_freqs

# bigram_freqs = {a+b:0 for (a,b) in itertools.product(
#             string.ascii_lowercase, string.ascii_lowercase)}

# %%
# english bigrams
eng_gram = collections.Counter()
for name in english_names:
    eng_gram.update(Counter(name[idx : idx + 2] for idx in range(len(name) - 1)))
# Out:
# {'fa': 3,
#  'ai': 4,
#  'ir': 8,
#  'rh': 4,
#  'hu': 6,
#  'ur': 18,
#  'rs': 10,
#  'st': 19,
#  'wa': 11,
#  'at': 10,
#  'te': 11,
#  'er': 49,
#  'ri': 19,
#  'id': 4,
#  'dg': 4,
#  'ge': 10,
#  'ne': 28,
#  'em': 6,
#  'me': 4,
#  'et': 8,
#  'th': 23,
#  'mo': 12,
#  'or': 23,
#  'ro': 15,
#  'on': 47,
#  'ey': 33,
#  'go': 4,
#  'oo': 9,
#  'od': 13,
#  'da': 6,
#  'al': 14,
#  'll': 33,
#  'ag': 6,
#  'ga': 10,
#  'ar': 40,
#  'ho': 15,
#  'no': 7,
#  'du': 4,
#  'ug': 5,
#  'gg': 5,
#  'an': 36,
#  'na': 6,
#  'as': 12,
#  'sh': 12,
#  'he': 10,
#  'rb': 3,
#  'be': 11,
#  'rt': 16,
#  'mc': 3,
#  'ca': 1,
#  'ia': 1,
#  'ty': 3,
#  'do': 10,
#  'ou': 15,
#  'ut': 6,
#  'hw': 1,
#  'it': 5,
#  'de': 19,
#  'el': 25,
#  'ak': 7,
#  'ke': 16,
#  'eh': 1,
#  'ha': 17,
#  'am': 14,
#  'ot': 4,
#  'tt': 12,
#  'tr': 7,
#  'ra': 25,
#  'ea': 10,
#  'mi': 3,
#  'is': 15,
#  'ka': 4,
#  'rn': 8,
#  'gr': 6,
#  're': 23,
#  'ee': 6,
#  'en': 26,
#  'nw': 2,
#  'wo': 9,
#  'ul': 9,
#  'lm': 4,
#  'ma': 20,
#  'ld': 13,
#  'dr': 6,
#  'ed': 7,
#  'rl': 7,
#  'li': 9,
#  'in': 37,
#  'ng': 14,
#  'gt': 3,
#  'to': 23,
#  'ju': 2,
#  'ud': 3,
#  'dd': 7,
#  'hi': 10,
#  'ic': 12,
#  'ck': 21,
#  'ks': 5,
#  'ay': 5,
#  'rv': 1,
#  'vi': 7,
#  'oa': 3,
#  'kl': 3,
#  'le': 37,
#  'rr': 10,
#  'so': 17,
#  'va': 4,
#  'au': 5,
#  'gh': 8,
#  'hn': 2,
#  'kn': 4,
#  'ox': 3,
#  'il': 13,
#  'es': 18,
#  'tl': 3,
#  'gi': 4,
#  'ib': 3,
#  'bb': 5,
#  'bi': 6,
#  'ns': 14,
#  'wh': 3,
#  'la': 17,
#  'ct': 1,
#  'ta': 6,
#  'ch': 7,
#  'oc': 7,
#  'rp': 2,
#  'pe': 14,
#  'nd': 14,
#  'gu': 4,
#  'un': 7,
#  'nt': 6,
#  'tu': 4,
#  'ei': 7,
#  'ss': 7,
#  'se': 14,
#  'ru': 5,
#  'uf': 2,
#  'ff': 3,
#  'ew': 2,
#  'ep': 1,
#  'pp': 3,
#  'pa': 8,
#  'rd': 11,
#  'ni': 5,
#  'ig': 5,
#  'av': 4,
#  've': 8,
#  'ue': 2,
#  'sm': 4,
#  'mu': 1,
#  'br': 4,
#  'ad': 7,
#  'ds': 6,
#  'aw': 5,
#  'ki': 9,
#  'gs': 2,
#  'ub': 2,
#  'nn': 13,
#  'su': 2,
#  'gd': 1,
#  'bu': 4,
#  'lo': 10,
#  'of': 2,
#  'ft': 2,
#  'us': 4,
#  'pr': 2,
#  'rg': 3,
#  'wr': 3,
#  'fr': 3,
#  'nc': 3,
#  'ci': 1,
#  'dl': 5,
#  'sy': 1,
#  'yk': 1,
#  'yn': 2,
#  'ol': 13,
#  'eg': 1,
#  'ja': 5,
#  'ac': 5,
#  'sa': 3,
#  'om': 4,
#  'sw': 3,
#  'sc': 2,
#  'co': 11,
#  'di': 7,
#  'po': 3,
#  'ow': 9,
#  'wi': 8,
#  'nf': 1,
#  'fo': 6,
#  'jo': 1,
#  'oh': 2,
#  'cc': 1,
#  'op': 5,
#  'pk': 1,
#  'dy': 2,
#  'yd': 2,
#  'ob': 3,
#  'kr': 1,
#  'ls': 5,
#  'ti': 5,
#  'ez': 1,
#  'oy': 3,
#  'wt': 1,
#  'lf': 2,
#  'af': 1,
#  'fe': 2,
#  'py': 1,
#  'yl': 3,
#  'um': 6,
#  'mn': 1,
#  'nu': 2,
#  'mb': 2,
#  'nl': 2,
#  'rw': 2,
#  'nr': 2,
#  'dm': 3,
#  'fi': 6,
#  'ix': 1,
#  'xo': 1,
#  'ap': 1,
#  'ko': 2,
#  'lk': 4,
#  'sf': 1,
#  'ie': 7,
#  'lr': 1,
#  'tw': 2,
#  'tc': 1,
#  'hl': 2,
#  'cu': 4,
#  'ya': 3,
#  'nm': 2,
#  'cr': 4,
#  'mp': 3,
#  'rm': 2,
#  'ye': 3,
#  'ok': 1,
#  'pl': 4,
#  'lu': 2,
#  'mm': 3,
#  'lc': 2,
#  'yo': 2,
#  'mk': 1,
#  'sn': 1,
#  'ov': 1,
#  'we': 8,
#  'ry': 5,
#  'wn': 4,
#  'bl': 2,
#  'km': 1,
#  'tz': 1,
#  'zp': 1,
#  'bo': 3,
#  'rk': 2,
#  'tm': 1,
#  'os': 3,
#  'si': 3,
#  'ky': 1,
#  'ab': 1,
#  'ms': 4,
#  'ef': 1,
#  'og': 2,
#  'fl': 2,
#  'ip': 2,
#  'gl': 2,
#  'ev': 2,
#  'vo': 1,
#  'by': 1,
#  'ba': 2,
#  'dw': 3,
#  'wl': 2,
#  'ui': 2,
#  'rc': 1,
#  'ce': 1,
#  'pu': 1,
#  'ys': 3,
#  'xv': 1,
#  'yr': 1,
#  'uv': 1,
#  'cl': 2,
#  'im': 3,
#  'ws': 1,
#  'sp': 2,
#  'lt': 2,
#  'eb': 2,
#  'my': 1,
#  'yt': 1,
#  'ph': 1,
#  'ps': 1,
#  'za': 1,
#  'ao': 1,
#  'ht': 2,
#  'ah': 2,
#  'if': 1,
#  'rf': 1,
#  'eo': 1,
#  'uh': 1,
#  'fu': 1,
#  'sd': 1,
#  'xa': 1,
#  'ts': 1}

# %%
dict(eng_gram)

# %%
[print(key, value) for (key, value) in sorted(eng_gram.items(), key=lambda x: x[1], reverse=True)]
# Out:
# er 49
# on 47
# ar 40
# in 37
# le 37
# an 36
# ey 33
# ll 33
# ne 28
# en 26
# el 25
# ra 25
# th 23
# or 23
# re 23
# to 23
# ck 21
# ma 20
# st 19
# ri 19
# de 19
# ur 18
# es 18
# ha 17
# so 17
# la 17
# rt 16
# ke 16
# ro 15
# ho 15
# ou 15
# is 15
# al 14
# am 14
# ng 14
# ns 14
# pe 14
# nd 14
# se 14
# od 13
# ld 13
# il 13
# nn 13
# ol 13
# mo 12
# as 12
# sh 12
# tt 12
# ic 12
# wa 11
# te 11
# be 11
# rd 11
# co 11
# rs 10
# at 10
# ge 10
# ga 10
# he 10
# do 10
# ea 10
# hi 10
# rr 10
# lo 10
# oo 9
# wo 9
# ul 9
# li 9
# ki 9
# ow 9
# ir 8
# et 8
# rn 8
# gh 8
# pa 8
# ve 8
# wi 8
# we 8
# no 7
# ak 7
# tr 7
# ed 7
# rl 7
# dd 7
# vi 7
# ch 7
# oc 7
# un 7
# ei 7
# ss 7
# ad 7
# di 7
# ie 7
# hu 6
# em 6
# da 6
# ag 6
# na 6
# ut 6
# gr 6
# ee 6
# dr 6
# bi 6
# ta 6
# nt 6
# ds 6
# fo 6
# um 6
# fi 6
# ug 5
# gg 5
# it 5
# ks 5
# ay 5
# au 5
# bb 5
# ru 5
# ni 5
# ig 5
# aw 5
# dl 5
# ja 5
# ac 5
# op 5
# ls 5
# ti 5
# ry 5
# ai 4
# rh 4
# id 4
# dg 4
# me 4
# go 4
# du 4
# ot 4
# ka 4
# lm 4
# va 4
# kn 4
# gi 4
# gu 4
# tu 4
# av 4
# sm 4
# br 4
# bu 4
# us 4
# om 4
# lk 4
# cu 4
# cr 4
# pl 4
# wn 4
# ms 4
# fa 3
# rb 3
# mc 3
# ty 3
# mi 3
# gt 3
# ud 3
# oa 3
# kl 3
# ox 3
# tl 3
# ib 3
# wh 3
# ff 3
# pp 3
# rg 3
# wr 3
# fr 3
# nc 3
# sa 3
# sw 3
# po 3
# ob 3
# oy 3
# yl 3
# dm 3
# ya 3
# mp 3
# ye 3
# mm 3
# bo 3
# os 3
# si 3
# dw 3
# ys 3
# im 3
# nw 2
# ju 2
# hn 2
# rp 2
# uf 2
# ew 2
# ue 2
# gs 2
# ub 2
# su 2
# of 2
# ft 2
# pr 2
# yn 2
# sc 2
# oh 2
# dy 2
# yd 2
# lf 2
# fe 2
# nu 2
# mb 2
# nl 2
# rw 2
# nr 2
# ko 2
# tw 2
# hl 2
# nm 2
# rm 2
# lu 2
# lc 2
# yo 2
# bl 2
# rk 2
# og 2
# fl 2
# ip 2
# gl 2
# ev 2
# ba 2
# wl 2
# ui 2
# cl 2
# sp 2
# lt 2
# eb 2
# ht 2
# ah 2
# ca 1
# ia 1
# hw 1
# eh 1
# rv 1
# ct 1
# ep 1
# mu 1
# gd 1
# ci 1
# sy 1
# yk 1
# eg 1
# nf 1
# jo 1
# cc 1
# pk 1
# kr 1
# ez 1
# wt 1
# af 1
# py 1
# mn 1
# ix 1
# xo 1
# ap 1
# sf 1
# lr 1
# tc 1
# ok 1
# mk 1
# sn 1
# ov 1
# km 1
# tz 1
# zp 1
# tm 1
# ky 1
# ab 1
# ef 1
# vo 1
# by 1
# rc 1
# ce 1
# pu 1
# xv 1
# yr 1
# uv 1
# ws 1
# my 1
# yt 1
# ph 1
# ps 1
# za 1
# ao 1
# if 1
# rf 1
# eo 1
# uh 1
# fu 1
# sd 1
# xa 1
# ts 1
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# russian bigrams
rus_gram = collections.Counter()
for name in english_names:
    eng_gram.update(Counter(name[idx : idx + 2] for idx in range(len(name) - 1)))

# %%
dict(english_bigrams)
# Out:
# {None: defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Fairhurst': 1.0}),
#  'Fairhurst': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wateridge': 1.0}),
#  'Wateridge': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Nemeth': 1.0}),
#  'Nemeth': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Moroney': 1.0}),
#  'Moroney': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Goodall': 1.0}),
#  'Goodall': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Agar': 1.0}),
#  'Agar': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thonon': 1.0}),
#  'Thonon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Duggan': 1.0}),
#  'Duggan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Nash': 1.0}),
#  'Nash': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Herbert': 1.0}),
#  'Herbert': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Mcarthur': 1.0}),
#  'Mcarthur': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Moriarty': 1.0}),
#  'Moriarty': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Douthwaite': 1.0}),
#  'Douthwaite': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dell': 1.0}),
#  'Dell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wakeham': 1.0}),
#  'Wakeham': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Mottram': 1.0}),
#  'Mottram': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Beamish': 1.0}),
#  'Beamish': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Karne': 1.0}),
#  'Karne': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Greenwood': 1.0}),
#  'Greenwood': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ullman': 1.0}),
#  'Ullman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Aldred': 1.0}),
#  'Aldred': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Darlington': 1.0}),
#  'Darlington': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Judd': 1.0}),
#  'Judd': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hicks': 1.0}),
#  'Hicks': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kay': 1.0}),
#  'Kay': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dervish': 1.0}),
#  'Dervish': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Oakley': 1.0}),
#  'Oakley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Morrison': 1.0}),
#  'Morrison': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bethell': 1.0}),
#  'Bethell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Vaughn': 1.0}),
#  'Vaughn': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Knox': 1.0}),
#  'Knox': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Iles': 1.0}),
#  'Iles': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Trattles': 1.0}),
#  'Trattles': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gibbins': 1.0}),
#  'Gibbins': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Whelan': 1.0}),
#  'Whelan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Mctaggart': 1.0}),
#  'Mctaggart': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Charnock': 1.0}),
#  'Charnock': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thorley': 1.0}),
#  'Thorley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thorpe': 1.0}),
#  'Thorpe': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Garland': 1.0}),
#  'Garland': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gunter': 1.0}),
#  'Gunter': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Turland': 1.0}),
#  'Turland': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Turney': 1.0}),
#  'Turney': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Reisser': 1.0}),
#  'Reisser': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ruff': 1.0}),
#  'Ruff': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Newall': 1.0}),
#  'Newall': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sheppard': 1.0}),
#  'Sheppard': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Knigge': 1.0}),
#  'Knigge': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Davey': 1.0}),
#  'Davey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rodrigues': 1.0}),
#  'Rodrigues': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Smullen': 1.0}),
#  'Smullen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Alam': 1.0}),
#  'Alam': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bradshaw': 1.0}),
#  'Bradshaw': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kingston': 1.0}),
#  'Kingston': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pelling': 1.0}),
#  'Pelling': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Auberton': 1.0}),
#  'Auberton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kennett': 1.0}),
#  'Kennett': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Newham': 1.0}),
#  'Newham': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ware': 1.0}),
#  'Ware': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Millar': 1.0}),
#  'Millar': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wallis': 1.0}),
#  'Wallis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sugden': 1.0}),
#  'Sugden': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Butler': 1.0}),
#  'Butler': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Lofthouse': 1.0}),
#  'Lofthouse': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Prendergast': 1.0}),
#  'Prendergast': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wragg': 1.0}),
#  'Wragg': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Francis': 1.0}),
#  'Francis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eddleston': 1.0}),
#  'Eddleston': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sykes': 1.0}),
#  'Sykes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thurston': 1.0}),
#  'Thurston': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ullmann': 1.0}),
#  'Ullmann': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Reynolds': 1.0}),
#  'Reynolds': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eggison': 1.0}),
#  'Eggison': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Jackson': 1.0}),
#  'Jackson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Savage': 1.0}),
#  'Savage': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ransom': 1.0}),
#  'Ransom': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Holdsworth': 1.0}),
#  'Holdsworth': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hiscocks': 1.0}),
#  'Hiscocks': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dick': 1.0}),
#  'Dick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Warden': 1.0}),
#  'Warden': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Powis': 1.0}),
#  'Powis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dunford': 1.0}),
#  'Dunford': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Vickars': 1.0}),
#  'Vickars': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Johns': 1.0}),
#  'Johns': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Mcconnell': 1.0}),
#  'Mcconnell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Leigh': 1.0}),
#  'Leigh': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gillan': 1.0}),
#  'Gillan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pennell': 1.0}),
#  'Pennell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Greening': 1.0}),
#  'Greening': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hopkinson': 1.0}),
#  'Hopkinson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Storey': 1.0}),
#  'Storey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dyde': 1.0}),
#  'Dyde': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Odam': 1.0}),
#  'Odam': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Robins': 1.0}),
#  'Robins': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thackray': 1.0}),
#  'Thackray': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Derrick': 1.0}),
#  'Derrick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Olson': 1.0}),
#  'Olson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Martinez': 1.0}),
#  'Martinez': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gascoyne': 1.0}),
#  'Gascoyne': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Lawther': 1.0}),
#  'Lawther': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Odonnell': 1.0}),
#  'Odonnell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wolf': 1.0}),
#  'Wolf': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rafferty': 1.0}),
#  'Rafferty': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Manson': 1.0}),
#  'Manson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pyle': 1.0}),
#  'Pyle': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Umney': 1.0}),
#  'Umney': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Number': 1.0}),
#  'Number': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Toland': 1.0}),
#  'Toland': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'More': 1.0}),
#  'More': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kenley': 1.0}),
#  'Kenley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Underwood': 1.0}),
#  'Underwood': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kinch': 1.0}),
#  'Kinch': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Monaghan': 1.0}),
#  'Monaghan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kenrick': 1.0}),
#  'Kenrick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Redmond': 1.0}),
#  'Redmond': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Firth': 1.0}),
#  'Firth': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Essam': 1.0}),
#  'Essam': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rixon': 1.0}),
#  'Rixon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Isman': 1.0}),
#  'Isman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Trueman': 1.0}),
#  'Trueman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Neilsen': 1.0}),
#  'Neilsen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Tobin': 1.0}),
#  'Tobin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Napper': 1.0}),
#  'Napper': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Elsmore': 1.0}),
#  'Elsmore': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kore': 1.0}),
#  'Kore': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Shand': 1.0}),
#  'Shand': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Partington': 1.0}),
#  'Partington': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Parratt': 1.0}),
#  'Parratt': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Alker': 1.0}),
#  'Alker': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Neyland': 1.0}),
#  'Neyland': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pasfield': 1.0}),
#  'Pasfield': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kilroy': 1.0}),
#  'Kilroy': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Tarrant': 1.0}),
#  'Tarrant': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Elkin': 1.0}),
#  'Elkin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Oatway': 1.0}),
#  'Oatway': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Leese': 1.0}),
#  'Leese': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Veitch': 1.0}),
#  'Veitch': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sellars': 1.0}),
#  'Sellars': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rudd': 1.0}),
#  'Rudd': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Oloughlin': 1.0}),
#  'Oloughlin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stockley': 1.0}),
#  'Stockley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Harrison': 1.0}),
#  'Harrison': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Grange': 1.0}),
#  'Grange': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Cullen': 1.0}),
#  'Cullen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Connell': 1.0}),
#  'Connell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Jardine': 1.0}),
#  'Jardine': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Yarwood': 1.0}),
#  'Yarwood': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ironman': 1.0}),
#  'Ironman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Crump': 1.0}),
#  'Crump': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Adler': 1.0}),
#  'Adler': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Yates': 1.0}),
#  'Yates': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Armer': 1.0}),
#  'Armer': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Reyes': 1.0}),
#  'Reyes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Brady': 1.0}),
#  'Brady': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stannard': 1.0}),
#  'Stannard': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Farhall': 1.0}),
#  'Farhall': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Crook': 1.0}),
#  'Crook': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thurlow': 1.0}),
#  'Thurlow': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Plummer': 1.0}),
#  'Plummer': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rainey': 1.0}),
#  'Rainey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Vinton': 1.0}),
#  'Vinton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Falconer': 1.0}),
#  'Falconer': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Yomkins': 1.0}),
#  'Yomkins': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bing': 1.0}),
#  'Bing': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Damon': 1.0}),
#  'Damon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Holder': 1.0}),
#  'Holder': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sneddon': 1.0}),
#  'Sneddon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hodson': 1.0}),
#  'Hodson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Polson': 1.0}),
#  'Polson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Tovar': 1.0}),
#  'Tovar': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Moran': 1.0}),
#  'Moran': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Virgo': 1.0}),
#  'Virgo': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Peake': 1.0}),
#  'Peake': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Collinson': 1.0}),
#  'Collinson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wells': 1.0}),
#  'Wells': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Drury': 1.0}),
#  'Drury': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Townsend': 1.0}),
#  'Townsend': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Longhurst': 1.0}),
#  'Longhurst': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bell': 1.0}),
#  'Bell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dibble': 1.0}),
#  'Dibble': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Fields': 1.0}),
#  'Fields': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Yardley': 1.0}),
#  'Yardley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Jackman': 1.0}),
#  'Jackman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Fitzpatrick': 1.0}),
#  'Fitzpatrick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Boden': 1.0}),
#  'Boden': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rousset': 1.0}),
#  'Rousset': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thornton': 1.0}),
#  'Thornton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Parkes': 1.0}),
#  'Parkes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Burns': 1.0}),
#  'Burns': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Chisholm': 1.0}),
#  'Chisholm': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Edgson': 1.0}),
#  'Edgson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Nutman': 1.0}),
#  'Nutman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Parmar': 1.0}),
#  'Parmar': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ventura': 1.0}),
#  'Ventura': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Veale': 1.0}),
#  'Veale': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Howell': 1.0}),
#  'Howell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Curley': 1.0}),
#  'Curley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ropple': 1.0}),
#  'Ropple': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wilkshire': 1.0}),
#  'Wilkshire': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rossi': 1.0}),
#  'Rossi': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sutherland': 1.0}),
#  'Sutherland': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ohara': 1.0}),
#  'Ohara': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kydd': 1.0}),
#  'Kydd': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Verdon': 1.0}),
#  'Verdon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wootton': 1.0}),
#  'Wootton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Abrams': 1.0}),
#  'Abrams': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Morton': 1.0}),
#  'Morton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stringer': 1.0}),
#  'Stringer': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Jarratt': 1.0}),
#  'Jarratt': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wakefield': 1.0}),
#  'Wakefield': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rogerson': 1.0}),
#  'Rogerson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gould': 1.0}),
#  'Gould': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Flannery': 1.0}),
#  'Flannery': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Shipley': 1.0}),
#  'Shipley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Twine': 1.0}),
#  'Twine': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wooldridge': 1.0}),
#  'Wooldridge': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kinrade': 1.0}),
#  'Kinrade': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Glenn': 1.0}),
#  'Glenn': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Prevost': 1.0}),
#  'Prevost': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Waite': 1.0}),
#  'Waite': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Binnington': 1.0}),
#  'Binnington': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Travill': 1.0}),
#  'Travill': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kirby': 1.0}),
#  'Kirby': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Baldwin': 1.0}),
#  'Baldwin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Lawlor': 1.0}),
#  'Lawlor': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Maguire': 1.0}),
#  'Maguire': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pearce': 1.0}),
#  'Pearce': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pullen': 1.0}),
#  'Pullen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Perry': 1.0}),
#  'Perry': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Leys': 1.0}),
#  'Leys': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Knoxville': 1.0}),
#  'Knoxville': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eyre': 1.0}),
#  'Eyre': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Luttrell': 1.0}),
#  'Luttrell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Winman': 1.0}),
#  'Winman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eldridge': 1.0}),
#  'Eldridge': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Roche': 1.0}),
#  'Roche': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bouvet': 1.0}),
#  'Bouvet': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Foulkes': 1.0}),
#  'Foulkes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Easen': 1.0}),
#  'Easen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rhodes': 1.0}),
#  'Rhodes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Addison': 1.0}),
#  'Addison': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Temple': 1.0}),
#  'Temple': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Oddie': 1.0}),
#  'Oddie': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dougherty': 1.0}),
#  'Dougherty': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stack': 1.0}),
#  'Stack': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Clark': 1.0}),
#  'Clark': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Whittaker': 1.0}),
#  'Whittaker': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Astley': 1.0}),
#  'Astley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Simms': 1.0}),
#  'Simms': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Oaks': 1.0}),
#  'Oaks': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dawson': 1.0}),
#  'Dawson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Jasper': 1.0}),
#  'Jasper': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Downer': 1.0}),
#  'Downer': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pateman': 1.0}),
#  'Pateman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Deverell': 1.0}),
#  'Deverell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Peal': 1.0}),
#  'Peal': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Emery': 1.0}),
#  'Emery': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Youssouf': 1.0}),
#  'Youssouf': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Houlton': 1.0}),
#  'Houlton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Aldworth': 1.0}),
#  'Aldworth': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Elcock': 1.0}),
#  'Elcock': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Jubb': 1.0}),
#  'Jubb': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Petersen': 1.0}),
#  'Petersen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gander': 1.0}),
#  'Gander': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bateman': 1.0}),
#  'Bateman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Downey': 1.0}),
#  'Downey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dunlop': 1.0}),
#  'Dunlop': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dutt': 1.0}),
#  'Dutt': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Lakey': 1.0}),
#  'Lakey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gilmour': 1.0}),
#  'Gilmour': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eyles': 1.0}),
#  'Eyles': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Downes': 1.0}),
#  'Downes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Keeley': 1.0}),
#  'Keeley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rootham': 1.0}),
#  'Rootham': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bourne': 1.0}),
#  'Bourne': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Creasey': 1.0}),
#  'Creasey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Geyer': 1.0}),
#  'Geyer': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pendlebury': 1.0}),
#  'Pendlebury': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Tocher': 1.0}),
#  'Tocher': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Black': 1.0}),
#  'Black': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Killick': 1.0}),
#  'Killick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'West': 1.0}),
#  'West': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Keys': 1.0}),
#  'Keys': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Odling': 1.0}),
#  'Odling': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Arnott': 1.0}),
#  'Arnott': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ashley': 1.0}),
#  'Ashley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Fraser': 1.0}),
#  'Fraser': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Rick': 1.0}),
#  'Rick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Burge': 1.0}),
#  'Burge': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Florey': 1.0}),
#  'Florey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eedie': 1.0}),
#  'Eedie': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dowling': 1.0}),
#  'Dowling': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Aspey': 1.0}),
#  'Aspey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stedman': 1.0}),
#  'Stedman': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hibbert': 1.0}),
#  'Hibbert': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Eade': 1.0}),
#  'Eade': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Smyth': 1.0}),
#  'Smyth': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Philips': 1.0}),
#  'Philips': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hussein': 1.0}),
#  'Hussein': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wears': 1.0}),
#  'Wears': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Friend': 1.0}),
#  'Friend': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Pett': 1.0}),
#  'Pett': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Vancoller': 1.0}),
#  'Vancoller': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Glen': 1.0}),
#  'Glen': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Cresswell': 1.0}),
#  'Cresswell': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Lathey': 1.0}),
#  'Lathey': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Underhill': 1.0}),
#  'Underhill': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Webber': 1.0}),
#  'Webber': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Unsworth': 1.0}),
#  'Unsworth': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wickens': 1.0}),
#  'Wickens': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Zaoui': 1.0}),
#  'Zaoui': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Tidmarsh': 1.0}),
#  'Tidmarsh': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thorp': 1.0}),
#  'Thorp': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Harrop': 1.0}),
#  'Harrop': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Logan': 1.0}),
#  'Logan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Ingram': 1.0}),
#  'Ingram': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Keight': 1.0}),
#  'Keight': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Manning': 1.0}),
#  'Manning': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Curtis': 1.0}),
#  'Curtis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gunston': 1.0}),
#  'Gunston': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Graham': 1.0}),
#  'Graham': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Brett': 1.0}),
#  'Brett': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Driffield': 1.0}),
#  'Driffield': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Arah': 1.0}),
#  'Arah': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Denney': 1.0}),
#  'Denney': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Godwin': 1.0}),
#  'Godwin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Turford': 1.0}),
#  'Turford': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kaur': 1.0}),
#  'Kaur': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stock': 1.0}),
#  'Stock': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Stamp': 1.0}),
#  'Stamp': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Cummins': 1.0}),
#  'Cummins': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Cooper': 1.0}),
#  'Cooper': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Marr': 1.0}),
#  'Marr': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Alford': 1.0}),
#  'Alford': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Robe': 1.0}),
#  'Robe': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Norris': 1.0}),
#  'Norris': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Forbes': 1.0}),
#  'Forbes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hannam': 1.0}),
#  'Hannam': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gaudin': 1.0}),
#  'Gaudin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Kouma': 1.0}),
#  'Kouma': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Dolton': 1.0}),
#  'Dolton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Riley': 1.0}),
#  'Riley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Tickner': 1.0}),
#  'Tickner': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Grimshaw': 1.0}),
#  'Grimshaw': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Hinton': 1.0}),
#  'Hinton': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Leonard': 1.0}),
#  'Leonard': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sayers': 1.0}),
#  'Sayers': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Deeley': 1.0}),
#  'Deeley': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Close': 1.0}),
#  'Close': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Klein': 1.0}),
#  'Klein': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Chauhan': 1.0}),
#  'Chauhan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wray': 1.0}),
#  'Wray': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Poyser': 1.0}),
#  'Poyser': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Fulleron': 1.0}),
#  'Fulleron': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Sims': 1.0}),
#  'Sims': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Thomas': 1.0}),
#  'Thomas': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Weaver': 1.0}),
#  'Weaver': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Gadsden': 1.0}),
#  'Gadsden': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Vinicombe': 1.0}),
#  'Vinicombe': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Fenwick': 1.0}),
#  'Fenwick': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Western': 1.0}),
#  'Western': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Foxall': 1.0}),
#  'Foxall': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Cowan': 1.0}),
#  'Cowan': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Wrightson': 1.0}),
#  'Wrightson': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Loft': 1.0}),
#  'Loft': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'Bird': 1.0}),
#  'Bird': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {None: 1.0})}

# %% [markdown]
# ------
# ## Multiple Linear Regression
#
# ------

# %% [markdown]
# ### Train/Test Data
#
# To make the data a little more accurate in it's predictions, we are going to split the surnames into train (65%) and test (35%) datasets.

# %%
# split the data to train the model
x_train, x_test, y_train, y_test = train_test_split(X, labels, test_size=0.35, random_state = 32)

# %%
y_train.shape

# %%
x_train.shape

# %% [markdown]
# ### Linear Regression

# %%
russian_model = LinearRegression()
russian_model.fit(x_train, y_train)

# %%
intercept = russian_model.intercept_
intercept

# %%
weight = russian_model.coef_
weight

# %% [markdown]
# ### Test Data and Predictions

# %%
surname_test['label'] = [1 if x =='Russian' else 0 for x in surname_test['nationality']]
labels = surname_test["label"]

# %%
# test data
cv_feature = cv.fit_transform(surname_test_list)
tf_transformer = TfidfTransformer(use_idf=False).fit(cv_feature)
reshape_feature = tf_transformer.transform(cv_feature)

# %%
russianess = russian_model.predict(reshape_feature)
russianess

# %% [markdown]
# #### -Model Summary-

# %%
# convert to same type as russianess (y_pred)
reshape_feature = reshape_feature.toarray()

# %%
from statsmodels.api import OLS
OLS(labels,russianess).fit().summary()

# %% [markdown]
# #### -Observations-

# %%
pred_name1 = ["Wasem"]
reshape_feature = cv.transform(pred_name1)
russian_model.predict(reshape_feature)

# %% [markdown]
# Note: __Wasem__ is an Arabic name. Model seems to think it is Russian due to similarity is spelling. Misclassified.

# %%
pred_name2 = ["See"]
reshape_feature = cv.transform(pred_name2)
russian_model.predict(reshape_feature)

# %% [markdown]
# Note: __See__ is a dutch name. This is correct.

# %%
pred_name3 = ["Los"]
reshape_feature = cv.transform(pred_name3)
russian_model.predict(reshape_feature)

# %% [markdown]
# Note: __Los__ is a Russian name. This has been misclassified as not Russian most likely due to Spanish having a similar name.
